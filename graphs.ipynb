# %%
import matplotlib.pyplot as plt

#loss: 0.5119 - accuracy: 0.3542 - val_loss: 0.3179 - val_accuracy: 0.3679

#loss: 0.3221 - accuracy: 0.3826 - val_loss: 0.3002 - val_accuracy: 0.4000

#loss: 0.3066 - accuracy: 0.3889 - val_loss: 0.2937 - val_accuracy: 0.3998

#loss: 0.2995 - accuracy: 0.3897 - val_loss: 0.2859 - val_accuracy: 0.3951

#loss: 0.2935 - accuracy: 0.3925 - val_loss: 0.2826 - val_accuracy: 0.3995

#loss: 0.2899 - accuracy: 0.3934 - val_loss: 0.2790 - val_accuracy: 0.3995

#loss: 0.2874 - accuracy: 0.3923 - val_loss: 0.2790 - val_accuracy: 0.3946

#loss: 0.2846 - accuracy: 0.3913 - val_loss: 0.2748 - val_accuracy: 0.3980

#loss: 0.2833 - accuracy: 0.3909 - val_loss: 0.2738 - val_accuracy: 0.3975

#loss: 0.2817 - accuracy: 0.3902 - val_loss: 0.2733 - val_accuracy: 0.4000

#loss: 0.2799 - accuracy: 0.3902 - val_loss: 0.2722 - val_accuracy: 0.4000

#loss: 0.2790 - accuracy: 0.3888 - val_loss: 0.2710 - val_accuracy: 0.3993

#loss: 0.2783 - accuracy: 0.3898 - val_loss: 0.2704 - val_accuracy: 0.4000

#loss: 0.2772 - accuracy: 0.3896 - val_loss: 0.2699 - val_accuracy: 0.4000

#loss: 0.2772 - accuracy: 0.3880 - val_loss: 0.2686 - val_accuracy: 0.4000

#loss: 0.2698 - accuracy: 0.3999
# Validation Loss: 0.26975682377815247, Validation Accuracy: 0.3999387323856354
# 128/128 [==============================] - 6s 44ms/step
# F1 Score: 0.8306956620744621
# Recall score: 0.8382352941176471
# Precision score: 0.8232904536222072
# Total number of parameters: 428132
# 128/128 [==============================] - 8s 65ms/step - loss: 0.2701 - accuracy: 0.4000
# Test Loss: 0.2700827419757843, Test Accuracy: 0.4000000059604645

#This is for regular accuracy
plt.figure(0)
plt.plot([0.5119,0.3221,0.3066,0.2995,0.2935,0.2899,0.2874,0.2846,0.2833,0.2817,0.2799,0.2790,0.2783,0.2772,0.2772])
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.title("Training Loss Over Epochs")
plt.savefig('trainingLoss.png')


plt.figure(1)
plt.plot([0.3542,0.3826,0.3889,0.3897,0.3925,0.3934,0.3923,0.3913,0.3909,0.3902,0.3902,0.3888,0.3898,0.3896,0.3880])
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.title("Training Accuracy Over Epochs")
plt.savefig('trainingAcc.png')

plt.figure(2)
plt.plot([0.3179,0.3002,0.2937,0.2859,0.2826,0.2790,0.2790,0.2748,0.2738,0.2733,0.2722,0.2710,0.2704,0.2699,0.2686])
plt.xlabel("Epoch")
plt.ylabel("Validation loss")
plt.title("Validation Loss Over Epochs")
plt.savefig('validationLoss.png')

plt.figure(3)
plt.plot([0.3679,0.4000,0.3998,0.3951,0.3995,0.3995,0.3946,0.3980,0.3975,0.4000,0.4000,0.3993,0.4000,0.4000,0.4000])
plt.xlabel("Epoch")
plt.ylabel("Validation accuracy")
plt.title("Validation Accuarcy Over Epochs")
plt.savefig('validationAcc.png')

# %%
import matplotlib.pyplot as plt
#loss: 0.5026 - binary_accuracy: 0.7851 - val_loss: 0.3161 - val_binary_accuracy: 0.8099

#loss: 0.3155 - binary_accuracy: 0.8102 - val_loss: 0.2967 - val_binary_accuracy: 0.8156

#loss: 0.3031 - binary_accuracy: 0.8116 - val_loss: 0.2903 - val_binary_accuracy: 0.8153

#loss: 0.2963 - binary_accuracy: 0.8116 - val_loss: 0.2840 - val_binary_accuracy: 0.8154

#loss: 0.2908 - binary_accuracy: 0.8142 - val_loss: 0.2803 - val_binary_accuracy: 0.8170

#loss: 0.2864 - binary_accuracy: 0.8135 - val_loss: 0.2784 - val_binary_accuracy: 0.8165

#loss: 0.2842 - binary_accuracy: 0.8126 - val_loss: 0.2811 - val_binary_accuracy: 0.8132

#loss: 0.2820 - binary_accuracy: 0.8134 - val_loss: 0.2732 - val_binary_accuracy: 0.8192

#loss: 0.2804 - binary_accuracy: 0.8142 - val_loss: 0.2728 - val_binary_accuracy: 0.8158

#loss: 0.2788 - binary_accuracy: 0.8148 - val_loss: 0.2720 - val_binary_accuracy: 0.8161

#loss: 0.2772 - binary_accuracy: 0.8131 - val_loss: 0.2716 - val_binary_accuracy: 0.8180

#loss: 0.2758 - binary_accuracy: 0.8133 - val_loss: 0.2693 - val_binary_accuracy: 0.8160

#loss: 0.2753 - binary_accuracy: 0.8133 - val_loss: 0.2691 - val_binary_accuracy: 0.8179

#loss: 0.2751 - binary_accuracy: 0.8127 - val_loss: 0.2687 - val_binary_accuracy: 0.8164

#loss: 0.2734 - binary_accuracy: 0.8145 - val_loss: 0.2681 - val_binary_accuracy: 0.8180

plt.figure(0)
plt.plot([0.5026,0.3155,0.3031,0.2963,0.2908,0.2864,0.2842,0.2820,0.2804,0.2788,0.2772,0.2758,0.2753,0.2751,0.2734])
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.title("Training Loss Over Epochs")
plt.savefig('trainingLossBIN.png')



plt.figure(1)
plt.plot([0.7851,0.8102,0.8116,0.8116,0.8142,0.8135,0.8126,0.8134,0.8142,0.8148,0.8131,0.8133,0.8133,0.8127,0.8145])
plt.xlabel("Epoch")
plt.ylabel("Training Binary Accuracy")
plt.title("Training Binary Accuarcy Over Epochs")
plt.savefig('trainingAccBIN.png')


plt.figure(2)
plt.plot([0.3161,0.2967,0.2903,0.2840,0.2803,0.2784,0.2811,0.2732,0.2728,0.2720,0.2716,0.2693,0.2691,0.2687,0.2681])
plt.xlabel("Epoch")
plt.ylabel("Validation loss")
plt.title("Validation Loss Over Epochs")
plt.savefig('validationLossBIN.png')


plt.figure(3)
plt.plot([0.8099,0.8156,0.8153,0.8154,0.8170,0.8165,0.8132,0.8192,0.8158,0.8161,0.8180,0.8160,0.8179,0.8164,0.8180])
plt.xlabel("Epoch")
plt.ylabel("Validation Binary accuracy")
plt.title("Validation Binary Accuracy Over Epochs")
plt.savefig('validationAccBIN.png')




# 61s 60ms/step - loss: 0.2694 - binary_accuracy: 0.8151
# Validation Loss: 0.26943907141685486, Validation Accuracy: 0.815073549747467
# 128/128 [==============================] - 8s 63ms/step
# F1 Score: 0.840047393364929
# Recall score: 0.8960248161764706
# Precision score: 0.7906528791565288
# Total number of parameters: 428132
# 128/128 [==============================] - 33s 263ms/step - loss: 0.2699 - binary_accuracy: 0.8151
# Test Loss: 0.2698585093021393, Test Accuracy: 0.815073549747467

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
def dipFinder(filePath):#filePath is the exoplanet csv file. MOlecule is just the name of the molecule to find dips.
    df=pd.read_csv(filePath)
    wavelengths=df["CENTRALWAVELNG"]
    transitDepths=df["PL_TRANDEP"]
    derivative=np.gradient(transitDepths,wavelengths)
    dipIndexes=np.where(derivative<0)[0]
    dipLocation=[wavelengths[i] for i in dipIndexes]#Gets what wavelength they are at
    dipValue=[transitDepths[i] for i in dipIndexes]#Gets the transit detph at that point
    return (dipLocation,dipValue)
filePath=r"C:\Users\Tristan\Downloads\table_HAT-P-18-b-Fu-et-al.-2022.csv"
data=pd.read_csv(filePath)

wavelengths=data["CENTRALWAVELNG"]
transitDepths=data["PL_TRANDEP"]
derivative=np.gradient(transitDepths,wavelengths)
dipIndexes = np.where((transitDepths < np.roll(transitDepths, 1)) & (transitDepths < np.roll(transitDepths, -1)))[0]
dipLocation=[wavelengths[i] for i in dipIndexes]#Gets what wavelength they are at
print(dipLocation)
dipValue=[transitDepths[i] for i in dipIndexes]#Gets the transit detph at that point


data=pd.read_csv(filePath)
plt.figure(figsize=(15, 15))
plt.title("HAT-P-18 b Fu et al. 2022 Spectrum Preview, with dips")
plt.plot(wavelengths,transitDepths)
plt.scatter(dipLocation,dipValue,color="red")
plt.show(block=True)
# plt.plot(locations,"r")
# Out:
# [2.74347, 2.74551, 2.74755, 2.74959, 2.75095, 2.75299, 2.75571, 2.75843, 2.75979, 2.76251, 2.76454, 2.76659, 2.76998, 2.77134, 2.77338, 2.77474, 2.7761, 2.77814, 2.7795, 2.78221, 2.78697, 2.78833, 2.79173, 2.79309, 2.79513, 2.79649, 2.79853, 2.79988, 2.80124, 2.80328, 2.80532, 2.80668, 2.80804, 2.81008, 2.81279, 2.81415, 2.81619, 2.81959, 2.82095, 2.82299, 2.82435, 2.8257, 2.82774, 2.8291, 2.8325, 2.83521, 2.83725, 2.83929, 2.84133, 2.84405, 2.84676, 2.8488, 2.85084, 2.85424, 2.85627, 2.85831, 2.86103, 2.86307, 2.86442, 2.86714, 2.86986, 2.87189, 2.87461, 2.87597, 2.87801, 2.88072, 2.88208, 2.88412, 2.88548, 2.88684, 2.88955, 2.89091, 2.89295, 2.89499, 2.89702, 2.89906, 2.90042, 2.90178, 2.90313, 2.90585, 2.90721, 2.90992, 2.91196, 2.91467, 2.91603, 2.91739, 2.91943, 2.92079, 2.9235, 2.92622, 2.92757, 2.92961, 2.93233, 2.93436, 2.9364, 2.93844, 2.94047, 2.94183, 2.94319, 2.94455, 2.94658, 2.9493, 2.95269, 2.95405, 2.9554, 2.95744, 2.95948, 2.96151, 2.96355, 2.96627, 2.96898, 2.97169,
# ...
